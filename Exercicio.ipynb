# %%
#cadastrar paciente

print('Você está no Menu Principal')
print('1. Cadastrar paciente OU 2. Sair')
opcao = input('Digite 1 ou 2: ')

if opcao == '1':  
    nome = input('Digite seu nome completo: ')
    print(f'Olá, {nome}!')

    telefone = input('Digite seu telefone: ')
    print(f'Seu telefone é {telefone}')

    pacienteNOME = [] 
    pacienteTELEFONE = []

    pacienteNOME.append(nome)
    pacienteTELEFONE.append(telefone)
    print('Paciente cadastrado com sucesso!')

else:
    print('Sair do programa?')
# Out:
# Você está no Menu Principal
# 1. Cadastrar paciente OU 2. Sair
# Olá, Jana Silva!
# Seu telefone é 81991235689
# Paciente cadastrado com sucesso!

# %%
# Lista para armazenar os pacientes cadastrados
pacientesCadastrados = [ {'nome': 'Jana Silva', 'telefone': '81991235689'}]
print('Bem-vindo à marcação de consultas!')

#Cadastrar paciente
print('Menu Principal')
print('Digite 2. Marcar consulta')
opcao = input('Digite aqui')


if opcao == '2':
    if len(pacientesCadastrados) == 0:
        print('Nenhum paciente cadastrado.')
    else:
        print('Pacientes Cadastrados')
        for p, paciente in enumerate(pacientesCadastrados, start=1):
            print(f'{p}. Nome: {paciente['nome']}, Telefone: {paciente['telefone']}')
        
        numeroPaciente = input('Escolha o número correspondente ao paciente para marcar a consulta: ')
        indice = int(numeroPaciente) - 1
        if 0 <= indice < len(pacientesCadastrados):
            paciente = pacientesCadastrados[indice]
            dia = input('Digite o dia da consulta (dd/mm/aaaa):')
            hora = input('Digite a hora da consulta (hh:mm):')
            especialidade = input('Digite a especialidade desejada para a consulta:')

            print('Consulta marcada:')
            print(f'Paciente: {paciente['nome']}, Dia: {dia}, Hora: {hora}, Especialidade: {especialidade}')
        else:
            print('Escolha inválida.')

# Encerrar programa
print('Programa encerrado.')
# Out:
# Bem-vindo à marcação de consultas!
# Menu Principal
# Digite 2. Marcar consulta
# Pacientes Cadastrados
# 1. Nome: Jana Silva, Telefone: 81991235689
# Consulta marcada:
# Paciente: Jana Silva, Dia: 12/02/2024, Hora: 12:00, Especialidade: psiquiatra
# Programa encerrado.

# %%
pacientesCadastrados = [{'nome': 'Jana Silva', 'telefone':'81991235689'}]

#agendamentos 
agendamentos = [{'paciente': 'Jana Silva', 'dia': '12/02/2024', 'hora': '12:00', 'especialidade': 'Psiquiatria'}]

print('Menu Principal')
print('Digite 3. Cancelar consulta')
opcao = input('Digite aqui')

if opcao == '3':  
    if len(agendamentos) == 0:
        print('Nenhuma consulta agendada.')
    else:
        print('Consultas agendadas')
        for a, agendamento in enumerate(agendamentos, start=1):
            print(f"{a}. Paciente: {agendamento['paciente']}, Dia: {agendamento['dia']}, Hora: {agendamento['hora']}, Especialidade: {agendamento['especialidade']}")
        
        numeroAgendamento = input('Escolha o número correspondente ao agendamento para cancelar: ')
        indice = int(numeroAgendamento) - 1
        if 0 <= indice < len(agendamentos):
            agendamento = agendamentos[indice]
            print('Consulta cancelada:')
            print(f'Paciente: {agendamento["paciente"]}, Dia: {agendamento["dia"]}, Hora: {agendamento["hora"]}, Especialidade: {agendamento["especialidade"]}')
            agendamentos.pop(indice)
        else:
            print('Escolha inválida.')

# Encerrar programa
print('Programa encerrado.')
# Out:
# Menu Principal
# Digite 3. Cancelar consulta
# Consultas agendadas
# 1. Paciente: Jana Silva, Dia: 12/02/2024, Hora: 12:00, Especialidade: Psiquiatria
# Consulta cancelada:
# Paciente: Jana Silva, Dia: 12/02/2024, Hora: 12:00, Especialidade: Psiquiatria
# Programa encerrado.

# %%
pacientesCadastrados = [{'nome': 'Jana Silva', 'telefone': '81991235689'}]
agendamentos = [{'paciente': 'Jana Silva', 'dia': '12/02/2024', 'hora': '12:00', 'especialidade': 'Psiquiatria'}]

#Cancelamento concluído
cancelamento = True

# Verificar se houve cancelamento
if cancelamento:
    print('Consulta cancelada com sucesso!')
else:
    print('Cancelamento não concluído.')

print('Menu Principal')
print('Digite 4. Sair')
opcao = input('Digite aqui')

if opcao == '4':
    print('Programa encerrado.')
else:
    print('Opção inválida.')
# Out:
# Consulta cancelada com sucesso!
# Menu Principal
# Digite 4. Sair
# Programa encerrado.

# %%
import datetime  # módulo datetime

pacientesCadastrados = [{'nome': 'Jana Silva', 'telefone': '81991235689'}]
agendamentos = [{'paciente': 'Jana Silva', 'dia': '12/02/2024', 'hora': '12:00', 'especialidade': 'Psiquiatria'}]

while True:
    print('Menu Principal')
    print('Digite 1. Cadastrar paciente')
    print('Digite 2. Marcar consulta')
    print('Digite 3. Cancelar consulta')
    print('Digite 4. Sair')
    opcao = input('Digite aqui 1. Cadastrar paciente, 2. Marcar consulta, 3. Cancelar consulta ou 4. Sair: ')

    if opcao == '1':
        nome = input('Digite o nome do paciente: ')
        telefone = input('Digite o telefone do paciente: ')


        # Verificar se o paciente está cadastrado
        pacienteCadastrado = False
        for paciente in pacientesCadastrados:
            if paciente['nome'] == pacienteNome:
                pacienteCadastrado = True
                break
        
        if pacienteCadastrado:
            print('Paciente já cadastrado!')
        else:
            pacientesCadastrados.append({'nome': nome, 'telefone': telefone})
            print('Paciente cadastrado com sucesso!')

    elif opcao == '2':
        # Marcação da consulta
        pacienteNome = input('Digite o nome do paciente: ')
        dia = input('Digite o dia da consulta (dd/mm/aaaa): ')
        hora = input('Digite a hora da consulta (hh:mm): ')

        # Verificar se o paciente está cadastrado
        pacienteCadastrado = False
        for paciente in pacientesCadastrados:
            if paciente['nome'] == pacienteNome:
                pacienteCadastrado = True
                break
        
        # Verificar se a consulta pode ser marcada
        consultaDisponivel = True
        for agendamento in agendamentos:
            if agendamento['dia'] == dia and agendamento['hora'] == hora:
                consulta_disponivel = False
                break
        
        consultaRetroativa = False
        dataHoje = datetime.datetime.now().strftime('%d/%m/%Y')
        dataConsulta = datetime.datetime.strptime(dia, '%d/%m/%Y').strftime('%d/%m/%Y')
        if dataConsulta < dataHoje:
            consultaRetroativa = True
        
        if not pacienteCadastrado:
            print('Paciente não cadastrado!')
        elif not consultaDisponivel:
            print('Este horário já está agendado!')
        elif consultaRetroativa:
            print('Não é possível agendar consultas retroativas!')
        else:
            agendamentos.append({'paciente': pacienteNome, 'dia': dia, 'hora': hora})
            print('Consulta marcada com sucesso!')

    elif opcao == '3':
        # Cancelar consulta
        if len(agendamentos) == 0:
            print('Nenhuma consulta agendada.')
        else:
            print('Consultas agendadas:')
            for a, agendamento in enumerate(agendamentos, start=1):
                print(f"{a}. Paciente: {agendamento['paciente']}, Dia: {agendamento['dia']}, Hora: {agendamento['hora']}, Especialidade: {agendamento.get('especialidade', 'N/A')}")

            numeroAgendamento = input('Escolha o número correspondente ao agendamento para cancelar: ')
            indice = int(numeroAgendamento) - 1
            if 0 <= indice < len(agendamentos):
                agendamento = agendamentos[indice]
                print('Consulta cancelada:')
                print(f'Paciente: {agendamento["paciente"]}, Dia: {agendamento["dia"]}, Hora: {agendamento["hora"]}')
                agendamentos.pop(indice)
            else:
                print('Escolha inválida.')

    elif opcao == '4':
        print('Programa encerrado.')
        break

    else:
        print('Opção inválida. Tente novamente.')
# Out:
# Menu Principal
# Digite 1. Cadastrar paciente
# Digite 2. Marcar consulta
# Digite 3. Cancelar consulta
# Digite 4. Sair
# Consultas agendadas:
# 1. Paciente: Jana Silva, Dia: 12/02/2024, Hora: 12:00, Especialidade: Psiquiatria
# Consulta cancelada:
# Paciente: Jana Silva, Dia: 12/02/2024, Hora: 12:00
# Menu Principal
# Digite 1. Cadastrar paciente
# Digite 2. Marcar consulta
# Digite 3. Cancelar consulta
# Digite 4. Sair
# Programa encerrado.
